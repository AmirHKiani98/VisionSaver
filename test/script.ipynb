# %% [markdown]
# ```js
# function U() {
#         return "xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g, function(c) {
#             var f = 16 * Math.random() | 0;
#             return ("x" === c ? f : f & 3 | 8).toString(16)
#         })
#     }
# ```

# %%
import uuid

def generate_uuid_v4():
    return str(uuid.uuid4())

# Example usage:
print(generate_uuid_v4())
# Out:
# 9f1f1123-ef6b-4dbe-890b-eeed538813ea

# %% [markdown]
# ```js
# function Q(c) {
#         c = $(c).find("SOAP-ENV\\:Fault");
#         return 0 < c.length ? (c = $(c).find("SOAP-ENV\\:Reason").text(),
#         debugConsoleMessage(c, 3),
#         c) : ""
#     }
# ```

# %%
import xml.etree.ElementTree as ET

def get_soap_fault_reason(xml_string):
    """
    Parse the SOAP XML and return the text of the <SOAP-ENV:Reason> element if a fault is present.
    """
    try:
        root = ET.fromstring(xml_string)
        # Find the Fault element (namespace may vary)
        fault = root.find('.//{http://www.w3.org/2003/05/soap-envelope}Fault')
        
        return ""
    except Exception as e:
        # Optionally log or print the error
        return ""

# %% [markdown]
# ```js
#     function xa(c, f, k, h, m, d, a) {
#         console.log("f: ", f);
#         console.log("k: ", k);
#         console.log("h: ", h);
#         console.log("m: ", m);
#         console.log("d: ", d);
#         console.log("a: ", a);
#         // c: ptz
#         // f: null
#         // k: f() {}
#         // h: handleCameraError
#         // m: http://192.168.15.110:80/onvif/ptz
#         // d: payload/up.xml
#         // a: null
#         c = {};
#         anonymousMode && (c = {
#             "Rise-Anonymous": "Anonymous"
#         });
#         $.ajax({
#             url: m,
#             type: "POST",
#             contentType: "application/soap+xml; charset=utf-8",
#             dataType: "xml",
#             headers: c,
#             beforeSend: function(c) {
#                 null !== f && f(c)
#             },
#             async: !0,
#             data: d,
#             timeout: Vb,
#             success: function(c, d, f) {
#                 var m = Q(f.responseText);
#                 if ("" === m)
#                     m = $(f.responseText).find("RebootNeeded"),
#                     0 < m.length && m.text(),
#                     null !== k && k(c, d, f, k, h);
#                 else {
#                     debugConsoleMessage(m, 3);
#                     switch (m) {
#                     case "Sender not Authorized":
#                         d = "Invalid username or password provided.";
#                         break;
#                     case "Not Implemented":
#                         d = "This function is not available in the camera.";
#                         break;
#                     case "Validation constraint violation: invalid value in element 'extension:AutoFocusSensitivity'":
#                         d = "The command sent to the camera was not formatted properly.";
#                         break;
#                     default:
#                         d = 0 <= m.indexOf("Validation constraint violation: malformed XML in element") ? "The command sent to the camera was not formatted properly." : m
#                     }
#                     h(c, d, f)
#                 }
#             },
#             error: function(c, d, f) {
#                 switch (f) {
#                 case "timeout":
#                     c = "The camera did not respond within the timeout range.";
#                     break;
#                 case "Not Found":
#                     c = "The camera did not find an interpretor for the command.";
#                     break;
#                 default:
#                     if ("string" === typeof f)
#                         c = "" === f ? "An error occured while processing your request." : f;
#                     else if (c = Q(f.responseXML),
#                     null === c || void 0 === c)
#                         c = "Unknown SOAP error occured."
#                 }
#                 debugConsoleMessage("Error sending SOAP request.  Status:{0} Reason:{1}".format(d, c), 3);
#                 null !== h && null !== c && h(null, c, null)
#             }
#         })
#     }
# ```

# %%
import requests
# url = http://192.168.15.110:80/onvif/ptz
def post_request(url, data, headers=None, timeout=30):
    if headers is None:
        headers = {"Content-Type": "application/soap+xml; charset=utf-8"}
    response = requests.post(url, data=data, headers=headers, timeout=timeout)
    print("Status:", response.status_code)
    print(response.text)
    return response

# %% [markdown]
# ```js
#     function jb(c, f) {
#         // console.log("SOAP::jb called with parameters: {0}, {1}".format(c, f));
#         var k = U().substr(0, 19);
#         k = CryptoJS.enc.Utf8.parse(k);
#         k = CryptoJS.enc.Base64.stringify(k);
#         var h = CryptoJS.enc.Base64.parse(k).toString(CryptoJS.enc.Latin1)
#           , m = (new Date).toISOString();
#         f = CryptoJS.SHA1(CryptoJS.enc.Latin1.parse(h + m + f));
#         f = CryptoJS.enc.Base64.stringify(CryptoJS.enc.Hex.parse(f.toString()));
#         return "<s:Header xmlns:s='http://www.w3.org/2003/05/soap-envelope'><wsse:Security xmlns:wsse='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-wssecurity-secext-1.0.xsd' xmlns:wsu='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-wssecurity-utility-1.0.xsd'><wsse:UsernameToken><wsse:Username>" + c + "</wsse:Username><wsse:Password Type='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-username-token-profile-1.0#PasswordDigest'>" + f + "</wsse:Password><wsse:Nonce>" + k + "</wsse:Nonce><wsu:Created>" + m + "</wsu:Created></wsse:UsernameToken></wsse:Security></s:Header>"
#     }
# ```

# %%
import base64
import hashlib
import os
from datetime import datetime, timezone

def generate_wsse_header(username, password):
    # Generate a random 19-character nonce (UUID v4 style, base64-encoded)
    nonce_bytes = os.urandom(14)  # 14 bytes ≈ 19 base64 chars
    nonce_b64 = base64.b64encode(nonce_bytes).decode()[:19]
    # Decode nonce to Latin1 (simulate CryptoJS.enc.Base64.parse(k).toString(CryptoJS.enc.Latin1))
    nonce_bytes_decoded = base64.b64decode(nonce_b64 + '==')  # pad if needed
    nonce_latin1 = nonce_bytes_decoded.decode('latin1', errors='ignore')
    # Created timestamp in ISO format
    created = datetime.utcnow().isoformat(timespec='milliseconds') + 'Z'
    # PasswordDigest = Base64(SHA1(nonce_latin1 + created + password))
    digest_input = (nonce_latin1 + created + password).encode('latin1', errors='ignore')
    sha1 = hashlib.sha1()
    sha1.update(digest_input)
    password_digest = base64.b64encode(sha1.digest()).decode()
    # Build WSSE header XML
    wsse_header = (
        "<s:Header xmlns:s='http://www.w3.org/2003/05/soap-envelope'>"
        "<wsse:Security xmlns:wsse='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-wssecurity-secext-1.0.xsd' "
        "xmlns:wsu='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-wssecurity-utility-1.0.xsd'>"
        "<wsse:UsernameToken>"
        f"<wsse:Username>{username}</wsse:Username>"
        "<wsse:Password Type='http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-username-token-profile-1.0#PasswordDigest'>"
        f"{password_digest}</wsse:Password>"
        f"<wsse:Nonce>{nonce_b64}</wsse:Nonce>"
        f"<wsu:Created>{created}</wsu:Created>"
        "</wsse:UsernameToken>"
        "</wsse:Security>"
        "</s:Header>"
    )
    return wsse_header

# %% [markdown]
# ```js
# function g(c, f, k) {
#         // c: <ptz:ContinuousMove><ptz:ProfileToken>Profile1</ptz:ProfileToken><ptz:Velocity><schema:PanTilt x='0' y='-0.66' /></ptz:Velocity></ptz:ContinuousMove>
#         // f: ƒ () {
#         //     lastSpeed = lastDirection = ""
#         // }
#         // k: function handleCameraError(a, b, d) {...
#         var h = "all"
#           , m = $(c).first();
#         if (0 < m.length)
#             switch (m = m[0].nodeName,
#             m.substr(0, m.indexOf(":")).toLowerCase()) {
#             case "imaging":
#                 h = ja.imaging;
#                 break;
#             case "device":
#                 h = ja.device;
#                 break;
#             case "media":
#                 h = ja.media;
#                 break;
#             case "ptz":
#                 h = ja.ptz;
#                 break;
#             case "dio":
#                 h = ja.dio;
#                 break;
#             case "events":
#                 h = ja.events;
#                 break;
#             case "actions":
#                 h = ja.actions;
#                 break;
#             case "extension":
#                 h = ja.extension;
#                 break;
#             case "thermal":
#                 h = ja.thermal;
#                 break;
#             case "advsecurity":
#                 h = ja.advsecurity
#             }
#         c = "<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n<soap:Envelope xmlns:soap='http://www.w3.org/2003/05/soap-envelope' xmlns:schema='http://www.onvif.org/ver10/schema' xmlns:device='http://www.onvif.org/ver10/device/wsdl' xmlns:imaging='http://www.onvif.org/ver20/imaging/wsdl' xmlns:media='http://www.onvif.org/ver10/media/wsdl' xmlns:ptz='http://www.onvif.org/ver20/ptz/wsdl' xmlns:dio='http://www.onvif.org/ver10/deviceIO/wsdl' xmlns:events='http://www.onvif.org/ver10/events/wsdl' xmlns:actions='http://updates.costarhd.com/ver1/riseactionengine/wsdl' xmlns:thermal='http://updates.costarhd.com/ver1/risethermal/wsdl' xmlns:advsecurity='http://www.onvif.org/ver10/advancedsecurity/wsdl' xmlns:extension='http://updates.costarhd.com/ver1/extension/wsdl'>{0}<soap:Body>{1}</soap:Body></soap:Envelope>".format(jb(Wb, Xb), c);
#         m = "http:" === Ba ? "80" : "443";
#         var d = "" === Yb ? m : Yb;
#         m = Ba + "//" + kb + ":" + d + "/" + h;
#         d = Ba + "//" + kb + ":" + d + "/onvif/" + h;
#         "events" === h && (d = m);
#         xa(h, null, f, k, d, c, null)
#     }
# ```

# %%
import requests
from lxml import etree

# Map XML tag to ONVIF service endpoint
SERVICE_MAP = {
    "imaging": "imaging",
    "device": "device",
    "media": "media",
    "ptz": "ptz",
    "dio": "deviceio",
    "events": "events",
    "actions": "action",
    "extension": "extension",
    "thermal": "risethermal",
    "advsecurity": "advancedsecurity"
}

def g(xml_body, username, password, ip, protocol="http", port=None):
    # Parse the first tag to determine the ONVIF service
    first = xml_body.split(":")[0].strip("<>")
    print(first)  
    service = "all"
    for key in SERVICE_MAP:
        if first.lower().startswith(key):
            service = SERVICE_MAP[key]
            break

    # Build the SOAP envelope
    wsse_header = generate_wsse_header(username, password)
    envelope = (
        '<?xml version="1.0" encoding="UTF-8"?>\n'
        "<soap:Envelope xmlns:soap='http://www.w3.org/2003/05/soap-envelope' "
        "xmlns:schema='http://www.onvif.org/ver10/schema' "
        "xmlns:device='http://www.onvif.org/ver10/device/wsdl' "
        "xmlns:imaging='http://www.onvif.org/ver20/imaging/wsdl' "
        "xmlns:media='http://www.onvif.org/ver10/media/wsdl' "
        "xmlns:ptz='http://www.onvif.org/ver20/ptz/wsdl' "
        "xmlns:dio='http://www.onvif.org/ver10/deviceIO/wsdl' "
        "xmlns:events='http://www.onvif.org/ver10/events/wsdl' "
        "xmlns:actions='http://updates.costarhd.com/ver1/riseactionengine/wsdl' "
        "xmlns:thermal='http://updates.costarhd.com/ver1/risethermal/wsdl' "
        "xmlns:advsecurity='http://www.onvif.org/ver10/advancedsecurity/wsdl' "
        "xmlns:extension='http://updates.costarhd.com/ver1/extension/wsdl'>"
        f"{wsse_header}<soap:Body>{xml_body}</soap:Body></soap:Envelope>"
    )

    # Determine port and protocol
    if protocol == "http":
        default_port = "80"
    else:
        default_port = "443"
    port = port or default_port

    # Build endpoint URL
    base_url = f"{protocol}://{ip}:{port}"
    endpoint = f"{base_url}/onvif/{service}"

    # Send the SOAP request
    print(f"Sending to endpoint: {endpoint}")
    post_request(endpoint, envelope)

# Example usage:
# xml_body = "<ptz:ContinuousMove><ptz:ProfileToken>Profile1</ptz:ProfileToken><ptz:Velocity><schema:PanTilt x='0' y='-0.66'/></ptz:Velocity></ptz:ContinuousMove>"
# g(xml_body, "admin", "admin`", "192.168.15.110")

# %%
import time
xml_body = "<ptz:ContinuousMove><ptz:ProfileToken>Profile1</ptz:ProfileToken><ptz:Velocity><schema:PanTilt x='-10' y='0.03' /></ptz:Velocity></ptz:ContinuousMove>"
g(xml_body, "admin", "admin", "192.168.29.241", "http", 80)

time.sleep(3)
xml_body = "<ptz:Stop><ptz:ProfileToken>Profile1</ptz:ProfileToken><ptz:PanTilt>true</ptz:PanTilt></ptz:Stop>"
g(xml_body, "admin", "admin", "192.168.29.241", "http", 80)
# Out:
# ptz
# Sending to endpoint: http://192.168.29.241:80/onvif/ptz
# Status: 200
# ...

# %%
import requests
response = requests.get("http://192.168.29.241")
if response.status_code == 200:
    print("Connection successful!")
    # Print or process the response content if needed
    print(response.text)
else:
    print("Failed to connect, status code:", response.status_code)
# Out:
# Connection successful!
# ï»¿<!doctype html>
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta charset="utf-8">
#     <link href="scripts/jquery-ui.min.css?v3.0" rel="stylesheet" />
#     <link href="css/jquery.snippet.min.css?v3.0" rel="stylesheet" />
#     <link href="css/login.css?v3.0" rel="stylesheet" />
#     <link href="css/master.css?v3.0" rel="stylesheet" />
#     <link href="fonts/font-awesome/css/font-awesome.css?v3.0" rel="stylesheet" />
#     <link href="css/control_panel.css?v3.0" rel="stylesheet" />
#     <link href="css/tooltip2.css?v3.0" rel="stylesheet" />
#     <link href="css/tooltiptags.css?v3.0" rel="stylesheet" />
#     <link href="css/cp_tabs.css?v3.0" rel="stylesheet" />
#     <link href="css/setup.css?v3.0" rel="stylesheet" />
#     <link href="css/jquery-ui-slider-pips.css?v3.0" rel="stylesheet" />
#     <link href="css/slider.css?v3.0" rel="stylesheet" />
#     <link href="css/network.css?v3.0" rel="stylesheet" />
# ...

# %% [markdown]
# # Ken's request for manual data

# %%
import pandas as pd
import numpy as np
import json
with open("camera_data.json", "r") as file:
    data = json.load(file)["statistics"]
    df = pd.DataFrame(data)

# %%
df["time"] = pd.to_datetime(df["time"]).dt.tz_convert("US/Central")

# %%
df.to_csv("camera_data.csv", index=False)

# %%
grouped = df.groupby("time").sum()[["volume","throughCount", "leftTurnCount", "rightTurnCount"]].reset_index()
grouped = grouped.sort_values(by="time")

# %%
grouped
# Out:
#                          time  volume  throughCount  leftTurnCount  \
# 0   2025-07-13 19:00:00-05:00      61            34             27
# 1   2025-07-13 19:15:00-05:00      71            39             32
# 2   2025-07-13 19:30:00-05:00      52            25             27
# 3   2025-07-13 19:45:00-05:00      57            33             24
# 4   2025-07-13 20:00:00-05:00      51            33             18
# ..                        ...     ...           ...            ...
# 931 2025-07-24 07:15:00-05:00      23            11             12
# 932 2025-07-24 07:30:00-05:00      30             8             22
# 933 2025-07-24 07:45:00-05:00      22             9             13
# 934 2025-07-24 08:00:00-05:00      33            15             18
# 935 2025-07-24 08:15:00-05:00      30            17             13
#
#      rightTurnCount
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# ...

# %%
new_grouped = grouped.copy()
new_grouped["hour"] = new_grouped["time"].dt.hour
new_grouped["day"] = new_grouped["time"].dt.date
new_grouped["month"] = new_grouped["time"].dt.month
new_grouped["year"] = new_grouped["time"].dt.year
new_grouped["minutes"] = 59
grouped_by_hour = new_grouped.groupby(["year", "month", "day", "hour", "minutes"])[["volume", "throughCount", "leftTurnCount", "rightTurnCount"]].sum().reset_index()

# Convert 'day' from datetime.date to int for pd.to_datetime
grouped_by_hour["day"] = grouped_by_hour["day"].apply(lambda x: x.day if hasattr(x, "day") else int(str(x).split("-")[-1]))

grouped_by_hour["time"] = pd.to_datetime(grouped_by_hour[["year", "month", "day", "hour", "minutes"]])
grouped_by_hour = grouped_by_hour.drop(columns=["year", "month", "day", "hour", "minutes"])
grouped_by_hour
# Out:
#      volume  throughCount  leftTurnCount  rightTurnCount                time
# 0       241           131            110               0 2025-07-13 19:59:00
# 1       158            91             67               0 2025-07-13 20:59:00
# 2       174            94             80               0 2025-07-13 21:59:00
# 3        89            51             38               0 2025-07-13 22:59:00
# 4        37            21             16               0 2025-07-13 23:59:00
# ..      ...           ...            ...             ...                 ...
# 248       7             4              3               0 2025-07-24 04:59:00
# 249      37            28              9               0 2025-07-24 05:59:00
# 250      57            24             33               0 2025-07-24 06:59:00
# 251     102            39             63               0 2025-07-24 07:59:00
# 252      63            32             31               0 2025-07-24 08:59:00
#
# [253 rows x 5 columns]

# %%
from IPython.display import display
import pandas as pd
import re
from openpyxl import load_workbook
from openpyxl.styles import Alignment

# Ensure both DataFrames have the same dtype for 'time' and are both tz-aware before concatenation
if getattr(grouped_by_hour["time"].dt.tz, 'zone', None) is None:
    grouped_by_hour["time"] = grouped_by_hour["time"].dt.tz_localize("US/Central")

if getattr(grouped["time"].dt.tz, 'zone', None) is None:
    grouped["time"] = grouped["time"].dt.tz_localize("US/Central")

# Create a formatted time column as requested
def format_time(dt):
    if dt.minute == 59:
        return "Total hour"
    else:
        return dt.strftime("%Y-%m-%d %I:%M %p")

new_group = pd.concat([grouped, grouped_by_hour], ignore_index=True)
new_group.sort_values(by="time", inplace=True)
new_group["formatted_time"] = new_group["time"].apply(format_time)

# Display with the formatted_time column highlighted

def highlight_formatted_time(row):
    # If formatted_time is in the "%Y-%m-%d %I %p" format (i.e., ends with 'AM' or 'PM' and has no minutes)
    # then color the whole row gray, else only highlight the formatted_time cell
    val = row["time"]
    # Match pattern like '2025-07-13 07 PM' (no minutes)
    if val == "Total hour":
        return ['background-color: #0398fc; color: black'] * len(row)
    else:
        return ['background-color: #e0e0e0; color: black'] * len(row)
new_group["day"] = new_group["time"].dt.date # date is capturing the whole day as a date. so we don't need month and year
new_group["month"] = new_group["time"].dt.month
new_group["year"] = new_group["time"].dt.year
new_new_grouped = new_group.groupby(["year", "month","day"])
for name, group in new_new_grouped:
    # day number:
    day_number = group["time"].dt.day.iloc[0]
    month = group["time"].dt.month.iloc[0]
    year = group["time"].dt.year.iloc[0]
    group = group.drop(columns=["year","month","day", "time"])
    group = group.rename(columns={"formatted_time": "time", "leftTurnCount": "Left", "throughCount": "Thru", "rightTurnCount":"Right"})

    styled = group.style.apply(highlight_formatted_time, axis=1)
    # Save the figure inside folder datas
    # Save the styled DataFrame to Excel with centered columns and wider time column
    excel_path = f"datas/camera_data_{month}_{day_number}_{year}.xlsx"
    styled.to_excel(excel_path, index=False)

    # Adjust column width and alignment using openpyxl

    wb = load_workbook(excel_path)
    ws = wb.active

    # Find the column index for 'time' (or 'formatted_time')
    time_col_idx = None
    for idx, cell in enumerate(ws[1], 1):
        if cell.value in ("time", "formatted_time"):
            time_col_idx = idx
            break

    # Set all columns to center alignment
    for row in ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=1, max_col=ws.max_column):
        for cell in row:
            cell.alignment = Alignment(horizontal="center", vertical="center")

    # Make the time column wider
    if time_col_idx is not None:
        col_letter = ws.cell(row=1, column=time_col_idx).column_letter
        ws.column_dimensions[col_letter].width = 28

    wb.save(excel_path)
excel_path = f"datas/all.xlsx"
if "time" in new_group.columns and pd.api.types.is_datetime64_any_dtype(new_group["time"]):
    new_group["time"] = new_group["time"].dt.tz_localize(None)
new_group = new_group.drop(columns=["year", "month", "day", "time"])
new_group = new_group.rename(columns={"formatted_time": "time", "leftTurnCount": "Left", "throughCount": "Thru", "rightTurnCount":"Right"})

styled = new_group.style.apply(highlight_formatted_time, axis=1)
# Remove timezone info from datetime columns before saving to Excel

styled.to_excel(excel_path, index=False)

# Adjust column width and alignment using openpyxl

wb = load_workbook(excel_path)
ws = wb.active

# Find the column index for 'time' (or 'formatted_time')
time_col_idx = None
for idx, cell in enumerate(ws[1], 1):
    if cell.value in ("time", "formatted_time"):
        time_col_idx = idx
        break

# Set all columns to center alignment
for row in ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=1, max_col=ws.max_column):
    for cell in row:
        cell.alignment = Alignment(horizontal="center", vertical="center")

# Make the time column wider
if time_col_idx is not None:
    col_letter = ws.cell(row=1, column=time_col_idx).column_letter
    ws.column_dimensions[col_letter].width = 28

wb.save(excel_path)
